# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("train.csv")

print(df.head())
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
print("Shape:", df.shape)

print("\nColumns:")
print(df.columns.tolist())

print("\nDataset Information:")
df.info()
# Out:
# Shape: (9800, 18)
#
# Columns:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales']
#
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
# ...

# %%
print(df.isnull().sum())
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df = df.dropna()

# %%
print("Duplicates:", df.duplicated().sum())

df = df.drop_duplicates()

print("Duplicates after cleaning:", df.duplicated().sum())
# Out:
# Duplicates: 0
# Duplicates after cleaning: 0

# %%
print(df.columns.tolist())
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales']

# %%
print(df.select_dtypes(include='number').columns.tolist())
# Out:
# ['Row ID', 'Postal Code', 'Sales']

# %%
region_sales = df.groupby('Region')['Sales'].sum()

print(region_sales)
# Out:
# Region
# Central    492646.9132
# East       660589.3560
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
category_sales = df.groupby('Category')['Sales'].sum()

print(category_sales)
# Out:
# Category
# Furniture          723538.4757
# Office Supplies    703212.8240
# Technology         825856.1130
# Name: Sales, dtype: float64

# %%
plt.bar(category_sales.index, category_sales.values)
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.title("Sales by Category")
plt.show()

# %%
plt.hist(df['Sales'], bins=20)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.title("Distribution of Sales")
plt.show()

# %%
print(df.select_dtypes(include='number').columns.tolist())
# Out:
# ['Row ID', 'Postal Code', 'Sales']

# %%
plt.scatter(df['Postal Code'], df['Sales'])

plt.xlabel("Postal Code")
plt.ylabel("Sales")
plt.title("Postal Code vs Sales")
plt.show()

# %%
region_sales = df.groupby('Region')['Sales'].sum()

print(region_sales)
# Out:
# Region
# Central    492646.9132
# East       660589.3560
# South      389151.4590
# West       710219.6845
# Name: Sales, dtype: float64

# %%
plt.bar(region_sales.index, region_sales.values)

plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.title("Sales by Region")
plt.show()

# %%
category_sales = df.groupby('Category')['Sales'].sum()

print(category_sales)
# Out:
# Category
# Furniture          723538.4757
# Office Supplies    703212.8240
# Technology         825856.1130
# Name: Sales, dtype: float64

# %%
plt.bar(category_sales.index, category_sales.values)

plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.title("Sales by Category")
plt.show()

# %%
sales_trend = df['Sales'].head(20)

plt.plot(range(1, 21), sales_trend)

plt.xlabel("Transaction Number")
plt.ylabel("Sales")
plt.title("Sales Trend")
plt.show()

# %%
plt.bar(category_sales.index, category_sales.values)
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.title("Sales by Category")
plt.show()

# %%
sales_trend = df['Sales'].head(20)

plt.plot(range(1, 21), sales_trend)
plt.xlabel("Transaction Number")
plt.ylabel("Sales")
plt.title("Sales Trend")
plt.show()

# %%
plt.hist(df['Sales'], bins=20)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.title("Distribution of Sales")
plt.show()

# %%
plt.scatter(df['Postal Code'], df['Sales'])
plt.xlabel("Postal Code")
plt.ylabel("Sales")
plt.title("Postal Code vs Sales")
plt.show()

# %%
print(df.columns.tolist())
# Out:
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales']

# %% [markdown]
# EDA Summary
# The Superstore sales dataset was successfully imported and cleaned using Pandas.
#
# Missing values and duplicate records were checked and handled.
#
# Filtering and sorting were performed to identify important sales records.
#
# Sales statistics were calculated to understand overall sales performance.
#
# Region-wise and category-wise sales performance was analyzed using GroupBy.
#
# A bar chart was used to compare sales across categories/regions.
#
# A line chart was used to observe the sales trend over time.
#
# A histogram was used to understand the distribution of sales.
#
# A scatter plot was used to analyze the relationship between sales and another numerical variable.
#
# The analysis helps identify high-performing regions and categories.
#
# Recommendation: Focus on high-performing categories and regions, while reviewing low-performing areas to improve overall sales and profitability.
